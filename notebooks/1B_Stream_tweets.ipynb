# %% [markdown]
# # "Live" Tweets from Stream Tweepy API

# %% [markdown]
# Preliminary steps before using Twitter's API:
# 1. Sign-up for a twitter account
# 2. Register a twitter developer account (requires email or phone number)
# 3. Create a developer app (I went with the name BlockedRoads)
# 4. Obtain your 'Access token' and 'access token secret' in the developer dashboard

# %% [markdown]
# ## Part 1: Pull Live Tweets from Twitter using Tweepy and Streaming API - StreamListener
#
# Some resources:
# http://socialmedia-class.org/twittertutorial.html
# <br>https://www.dataquest.io/blog/streaming-data-python/

# %% [markdown]
# **Step 1: In terminal run:** `! pip install tweepy`

# %% [markdown]
# **Step 2: Load imports**

# %%
import pandas as pd
import tweepy
import json
import datetime
from tweepy.streaming import StreamListener
import shutil

# %% [markdown]
# **Step 2: Authenticate Twitter Credentials through Tweepy**

# %%
import config

# %%
# authenticate account with tweepy
auth = tweepy.OAuthHandler(config.consumer_key, config.consumer_secret)
auth.set_access_token(config.access_key, config.access_secret)

# create API object to pull data from twitter - and pass in code!
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# now we should be free to make twitter api calls!

# %% [markdown]
# **Step 3: Verify API is working with your account**

# %%
# check if program is working - output is your twitter name
user = api.me()
print (user.name)
# Out:
# amy taylor

# %%
# To send a Tweet from your account (assuming you allowed your app to have read/write permissions):
# api.update_status(status = "Hey, I'm tweeting with Tweepy!")

# %% [markdown]
# **Step 4: Instantiate the StreamListener class and start pulling tweets**
# - Specify how tweets are downloaded inside the `on_status` or `on_data` class method
# - `stream.filter` starts the download. Specify your search words with the `track` parameter
# - Other parameters available include: .....
# - **Use EX 2 for now**. To stop the live stream, kernel interrupt the codeblock
# - Continue to Part 2 to save the tweets into a json file

# %% [markdown]
# EX 1. StreamListener: prints the stream of texts directly in the codeblock

# %% [markdown]
# EX 2. StreamListener VERIFIED: saves tweets in a json file

# %%
# verified code block, DON'T DELETE!!!!!!!!!!!!!!!!!!!!!!!

class StreamListener(tweepy.StreamListener):            
    def on_data(self, status):   
        try:
            with open('../data/AT_stream/scrape.json', 'a') as f:
                f.write(status)
        except:
            print("Could not open file log")
        
         
    def on_error(self, status_code):
        if status_code == 420:
            return False

        
stream_listener = StreamListener()
stream = tweepy.Stream(auth=auth, listener= stream_listener)
# starts the stream
stream.filter(track=[ "road closed", "roads closed", "road blocked", "street blocked", "roadclosed"])
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     284         try:
# --> 285             return self.connection.recv_into(*args, **kwargs)
#     286         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-3d3f3f81509b> in <module>()
#      18 stream = tweepy.Stream(auth=auth, listener= stream_listener)
#      19 # starts the stream
# ---> 20 stream.filter(track=[ "road closed", "roads closed", "road blocked", "street blocked", "roadclosed"])
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     411             else:
#     412                 cache_content = False
# --> 413                 data = self._fp.read(amt)
#     414                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     415                     # Close the connection when no data is returned
#
# ~/anaconda3/envs/dsi/lib/python3.5/http/client.py in read(self, amt)
#     446             # Amount is given, implement using readinto
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#     450         else:
#
# ~/anaconda3/envs/dsi/lib/python3.5/http/client.py in readinto(self, b)
#     476
#     477         if self.chunked:
# --> 478             return self._readinto_chunked(b)
#     479
#     480         if self.length is not None:
#
# ~/anaconda3/envs/dsi/lib/python3.5/http/client.py in _readinto_chunked(self, b)
#     571         try:
#     572             while True:
# --> 573                 chunk_left = self._get_chunk_left()
#     574                 if chunk_left is None:
#     575                     return total_bytes
#
# ~/anaconda3/envs/dsi/lib/python3.5/http/client.py in _get_chunk_left(self)
#     539                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     540             try:
# --> 541                 chunk_left = self._read_next_chunk_size()
#     542             except ValueError:
#     543                 raise IncompleteRead(b'')
#
# ~/anaconda3/envs/dsi/lib/python3.5/http/client.py in _read_next_chunk_size(self)
#     499     def _read_next_chunk_size(self):
#     500         # Read the next chunk size from the file
# --> 501         line = self.fp.readline(_MAXLINE + 1)
#     502         if len(line) > _MAXLINE:
#     503             raise LineTooLong("chunk size")
#
# ~/anaconda3/envs/dsi/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295                 raise
#     296         except OpenSSL.SSL.WantReadError:
# --> 297             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     298                 raise timeout('The read operation timed out')
#     299             else:
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/envs/dsi/lib/python3.5/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# EX 3. StreamListener EXPERIMENTAL: testing out different params such as:
# - extended tweets
# - geolocated tweets

# %%
# EX 4: 
class StreamListener(tweepy.StreamListener):  
    
    
    def on_data(self, status):   
        try:
            with open('../data/AT_stream/scrape.json', 'w') as f:
                for tweet in status.items():
                    if status.place is not None:
                        f.write(jsonpickle.encode(tweet._json, unpicklable=False) + '\n')
                        tweetCount += 1
                print("Downloaded {0} tweets".format(tweetCount))
                
        except:
            print("Could not open file log")
        
         
    def on_error(self, status_code):
        if status_code == 420:
            return False

        
stream_listener = StreamListener()
stream = tweepy.Stream(auth=auth, listener= stream_listener)
# starts the stream
stream.filter(track=[ "road closed", "roads closed", "road blocked", "street blocked", "roadclosed"])
# Out:
# Could not open file log
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     284         try:
# --> 285             return self.connection.recv_into(*args, **kwargs)
#     286         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-0200de4694cc> in <module>
#      24 stream = tweepy.Stream(auth=auth, listener= stream_listener)
#      25 # starts the stream
# ---> 26 stream.filter(track=[ "road closed", "roads closed", "road blocked", "street blocked", "roadclosed"])
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     411             else:
#     412                 cache_content = False
# --> 413                 data = self._fp.read(amt)
#     414                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     415                     # Close the connection when no data is returned
#
# ~/anaconda3/envs/dsi/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~/anaconda3/envs/dsi/lib/python3.6/http/client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~/anaconda3/envs/dsi/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~/anaconda3/envs/dsi/lib/python3.6/http/client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~/anaconda3/envs/dsi/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~/anaconda3/envs/dsi/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295                 raise
#     296         except OpenSSL.SSL.WantReadError:
# --> 297             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     298                 raise timeout('The read operation timed out')
#     299             else:
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/envs/dsi/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# ## Part 2: Save Tweet to a JSON file (from any of the StreamListener options)

# %%
def file_conversion():
    #create a timestamp
    now = datetime.datetime.now()
    month = '0'+str(now.month)
    day = str(now.day)
    hour = str(now.hour)
    minute = str(now.minute)
    now_str = str(now.year)+month+day+'_'+hour+'_'+minute
    
    
    #replace the name of our file with a new timestamped filename
    dest = '../data/AT_stream/scrape_' + now_str + ".json"
    shutil.move('../data/AT_stream/scrape.json', dest)
    
    with open(dest, "r") as f:
        status = f.readlines()
        jsons = []
        for ind in status:
            jsons.append(json.loads(ind))
    return jsons

# %%
file_conversion()
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 16 20:14:10 +0000 2019',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1085631317751066626,
#   'id_str': '1085631317751066626',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'place': None,
#   'quote_count': 0,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 16 20:03:10 +0000 2019',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1085628549325864960',
#       'indices': [116, 139],
#       'url': 'https://t.co/eySlFQdCO8'}],
#     'user_mentions': []},
#    'extended_tweet': {'display_text_range': [0, 174],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'full_text': "Aaaaaaaaaaaand another mofo blocked. I told this nigga to stop tweeting to me about Street. This dude disrupted my damn TL for the past 2 days about Meth's weed carrier smdh."},
#    'favorite_count': 1,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 1085628549325864960,
#    'id_str': '1085628549325864960',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'quote_count': 2,
#    'reply_count': 1,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Aaaaaaaaaaaand another mofo blocked. I told this nigga to stop tweeting to me about Street. This dude disrupted my… https://t.co/eySlFQdCO8',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Sep 12 03:46:22 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Husband, Dad, Hip Hop Connoisseur, Producer, Writer, Hoops Addict, Vinyl Junkie, Lo Head, Book Worm, Bearded Barber, Marriage Coach & Host of Apt. 5B Podcast',
#     'favourites_count': 18401,
#     'follow_request_sent': None,
#     'followers_count': 9148,
#     'following': None,
#     'friends_count': 4041,
#     'geo_enabled': True,
#     'id': 73562852,
#     'id_str': '73562852',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 192,
#     'location': 'DMV via Philly',
#     'name': 'Kil',
#     'notifications': None,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/73562852/1427775122',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1078182920056176640/o_3x6jss_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1078182920056176640/o_3x6jss_normal.jpg',
#     'profile_link_color': '1F98C7',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Kil889',
#     'statuses_count': 146427,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://www.willmakebeatsforfood.com',
#     'utc_offset': None,
#     'verified': False}},
#   'quoted_status_id': 1085628549325864960,
#   'quoted_status_id_str': '1085628549325864960',
#   'quoted_status_permalink': {'display': 'twitter.com/kil889/status/…',
#    'expanded': 'https://twitter.com/kil889/status/1085628549325864960',
#    'url': 'https://t.co/2lBOETauaJ'},
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Just block anybody who willingly listens to Streetlife',
#   'timestamp_ms': '1547669650863',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Apr 03 01:38:23 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Recording/Audio Engineer x @Sycegame Send inquiries about Recording/Mixing/Mastering to MiqueOnTheMix@gmail.com',
#    'favourites_count': 2063,
#    'follow_request_sent': None,
#    'followers_count': 1337,
#    'following': None,
#    'friends_count': 1118,
#    'geo_enabled': True,
#    'id': 129052381,
#    'id_str': '129052381',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 24,
#    'location': 'Your Local Chipotle',
#    'name': 'Tragedy Khadafi verse on Strange Fruit',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/129052381/1395934402',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942770472739012610/7kC-x5C6_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942770472739012610/7kC-x5C6_normal.jpg',
#    'profile_link_color': 'B30000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '080D0F',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'MiqueOnTheMix',
#    'statuses_count': 138078,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://Soundcloud.com/miqueonthemix',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 16 20:14:13 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2335072347,
#      'id_str': '2335072347',
#      'indices': [3, 18],
#      'name': 'Black Nerd Problems',
#      'screen_name': 'BlkNrdProblems'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1085631330384334848,
#   'id_str': '1085631330384334848',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'place': None,
#   'quote_count': 0,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 16 16:04:10 +0000 2019',
#    'display_text_range': [16, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1085568402364743680',
#       'indices': [117, 140],
#       'url': 'https://t.co/bIeb77UYo3'}],
#     'user_mentions': [{'id': 2335072347,
#       'id_str': '2335072347',
#       'indices': [0, 15],
#       'name': 'Black Nerd Problems',
#       'screen_name': 'BlkNrdProblems'}]},
#    'extended_tweet': {'display_text_range': [16, 289],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 2335072347,
#        'id_str': '2335072347',
#        'indices': [0, 15],
#        'name': 'Black Nerd Problems',
#        'screen_name': 'BlkNrdProblems'}]},
#     'full_text': "@BlkNrdProblems Out of all the things Gillette did with this commercial, this was the only thing I really had a problem with. The guy was trying to approach a hot girl, this guy just up and cock-blocked him.\n\nThat's incredibly antisocial and annoying behavior, it's un calibrated behavior."},
#    'favorite_count': 0,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 1085568402364743680,
#    'id_str': '1085568402364743680',
#    'in_reply_to_screen_name': 'BlkNrdProblems',
#    'in_reply_to_status_id': 1085567467399929856,
#    'in_reply_to_status_id_str': '1085567467399929856',
#    'in_reply_to_user_id': 2335072347,
#    'in_reply_to_user_id_str': '2335072347',
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'quote_count': 1,
#    'reply_count': 2,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#    'text': '@BlkNrdProblems Out of all the things Gillette did with this commercial, this was the only thing I really had a pro… https://t.co/bIeb77UYo3',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Oct 09 15:39:02 +0000 2016',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Turtle',
#     'favourites_count': 1949,
#     'follow_request_sent': None,
#     'followers_count': 50,
#     'following': None,
#     'friends_count': 254,
#     'geo_enabled': False,
#     'id': 785142536419422208,
#     'id_str': '785142536419422208',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 3,
#     'location': 'New York, NY',
#     'name': 'Turtle',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/785142536419422208/1544932577',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1074151034673610752/xvcwVXcB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1074151034673610752/xvcwVXcB_normal.jpg',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'rhyemswturtle',
#     'statuses_count': 5052,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'quoted_status_id': 1085568402364743680,
#   'quoted_status_id_str': '1085568402364743680',
#   'quoted_status_permalink': {'display': 'twitter.com/rhyemswturtle/…',
#    'expanded': 'https://twitter.com/rhyemswturtle/status/1085568402364743680',
#    'url': 'https://t.co/gePkV1NM1N'},
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 16 18:59:47 +0000 2019',
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1085612595208306688',
#       'indices': [117, 140],
#       'url': 'https://t.co/eSZ5VtMYRL'}],
#     'user_mentions': []},
#    'extended_tweet': {'display_text_range': [0, 243],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/rhyemswturtle/…',
#        'expanded_url': 'https://twitter.com/rhyemswturtle/status/1085568402364743680',
#        'indices': [244, 267],
#        'url': 'https://t.co/gePkV1NM1N'}],
#      'user_mentions': []},
#     'full_text': "Beloved, that's called street harassment. Catcalling. Unwanted attention from dudes on the street that NO WOMAN WANTS. That's incredibly great on part of the male friend for stopping dude, it's called growing up and leaving womenfolk tf alone. https://t.co/gePkV1NM1N"},
#    'favorite_count': 57,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 1085612595208306688,
#    'id_str': '1085612595208306688',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'quote_count': 0,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Jan 16 16:04:10 +0000 2019',
#     'display_text_range': [16, 140],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1085568402364743680',
#        'indices': [117, 140],
#        'url': 'https://t.co/bIeb77UYo3'}],
#      'user_mentions': [{'id': 2335072347,
#        'id_str': '2335072347',
#        'indices': [0, 15],
#        'name': 'Black Nerd Problems',
#        'screen_name': 'BlkNrdProblems'}]},
#     'extended_tweet': {'display_text_range': [16, 289],
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'urls': [],
#       'user_mentions': [{'id': 2335072347,
#         'id_str': '2335072347',
#         'indices': [0, 15],
#         'name': 'Black Nerd Problems',
#         'screen_name': 'BlkNrdProblems'}]},
#      'full_text': "@BlkNrdProblems Out of all the things Gillette did with this commercial, this was the only thing I really had a problem with. The guy was trying to approach a hot girl, this guy just up and cock-blocked him.\n\nThat's incredibly antisocial and annoying behavior, it's un calibrated behavior."},
#     'favorite_count': 0,
#     'favorited': False,
#     'filter_level': 'low',
#     'geo': None,
#     'id': 1085568402364743680,
#     'id_str': '1085568402364743680',
#     'in_reply_to_screen_name': 'BlkNrdProblems',
#     'in_reply_to_status_id': 1085567467399929856,
#     'in_reply_to_status_id_str': '1085567467399929856',
#     'in_reply_to_user_id': 2335072347,
#     'in_reply_to_user_id_str': '2335072347',
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': None,
#     'quote_count': 1,
#     'reply_count': 2,
#     'retweet_count': 0,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#     'text': '@BlkNrdProblems Out of all the things Gillette did with this commercial, this was the only thing I really had a pro… https://t.co/bIeb77UYo3',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sun Oct 09 15:39:02 +0000 2016',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Turtle',
#      'favourites_count': 1949,
#      'follow_request_sent': None,
#      'followers_count': 50,
#      'following': None,
#      'friends_count': 254,
#      'geo_enabled': False,
#      'id': 785142536419422208,
#      'id_str': '785142536419422208',
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 3,
#      'location': 'New York, NY',
#      'name': 'Turtle',
#      'notifications': None,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/785142536419422208/1544932577',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1074151034673610752/xvcwVXcB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1074151034673610752/xvcwVXcB_normal.jpg',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'rhyemswturtle',
#      'statuses_count': 5052,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'quoted_status_id': 1085568402364743680,
#    'quoted_status_id_str': '1085568402364743680',
#    'quoted_status_permalink': {'display': 'twitter.com/rhyemswturtle/…',
#     'expanded': 'https://twitter.com/rhyemswturtle/status/1085568402364743680',
#     'url': 'https://t.co/gePkV1NM1N'},
#    'reply_count': 5,
#    'retweet_count': 21,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "Beloved, that's called street harassment. Catcalling. Unwanted attention from dudes on the street that NO WOMAN WAN… https://t.co/eSZ5VtMYRL",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Feb 10 05:39:57 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Official Twitter of Black Nerd Problems website. 99 problems, diversity ain't one. Nerdy & Lit AF. Email NOT DM! Contact: blacknerdproblems@gmail.com",
#     'favourites_count': 10249,
#     'follow_request_sent': None,
#     'followers_count': 37242,
#     'following': None,
#     'friends_count': 443,
#     'geo_enabled': True,
#     'id': 2335072347,
#     'id_str': '2335072347',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 514,
#     'location': 'New York, USA',
#     'name': 'Black Nerd Problems',
#     'notifications': None,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2335072347/1535989541',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/455751502515019776/m_tI4lYt_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/455751502515019776/m_tI4lYt_normal.jpeg',
#     'profile_link_color': 'FAB81E',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'BlkNrdProblems',
#     'statuses_count': 60583,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://www.blacknerdproblems.com',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "RT @BlkNrdProblems: Beloved, that's called street harassment. Catcalling. Unwanted attention from dudes on the street that NO WOMAN WANTS.…",
#   'timestamp_ms': '1547669653875',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Oct 24 15:46:11 +0000 2015',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Meme collector and connoisseur.\nA fan of facts.\nCapitalism kills.\n#XULA',
#    'favourites_count': 2295,
#    'follow_request_sent': None,
#    'followers_count': 360,
#    'following': None,
#    'friends_count': 312,
#    'geo_enabled': True,
#    'id': 4003773793,
#    'id_str': '4003773793',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3,
#    'location': 'St Louis, MO',
#    'name': "lmao y'all wild",
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4003773793/1462198720',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/971921809800093696/2U-eKs3I_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/971921809800093696/2U-eKs3I_normal.jpg',
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'AnAcidTweeter',
#    'statuses_count': 1833,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 16 20:14:15 +0000 2019',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1085631338693214208,
#   'id_str': '1085631338693214208',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'text': 'TFL UPDATE: TfLTrafficNews: London Road SM4 is closed in both directions due to a road traffic collision.',
#   'timestamp_ms': '1547669655856',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 04 20:11:00 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '#London #Property #Retweets just here to share some interesting things i see. #followme',
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 147,
#    'following': None,
#    'friends_count': 433,
#    'geo_enabled': False,
#    'id': 750059354565537792,
#    'id_str': '750059354565537792',
#    'is_translator': False,
#    'lang': 'en-gb',
#    'listed_count': 9,
#    'location': 'City of London, London',
#    'name': 'Bob',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/750059354565537792/1467665866',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/750071341471203329/29AJ59ux_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/750071341471203329/29AJ59ux_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'thelondonbob01',
#    'statuses_count': 104997,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jan 16 20:14:51 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 224671374,
#      'id_str': '224671374',
#      'indices': [3, 17],
#      'name': 'Highways England',
#      'screen_name': 'HighwaysNWEST'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1085631487955869697,
#   'id_str': '1085631487955869697',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 16 18:15:07 +0000 2019',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1085601354284961797',
#       'indices': [117, 140],
#       'url': 'https://t.co/NnLxpEMYHC'}],
#     'user_mentions': []},
#    'extended_tweet': {'display_text_range': [0, 279],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'full_text': 'All traffic caught within the closure has now been released. Thanks for your patience if you were held up. The road remains closed between J35 and J36 northbound whilst Police carry out their collision investigation works. Traffic is being diverted via the solid triangle symbol.'},
#    'favorite_count': 2,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 1085601354284961797,
#    'id_str': '1085601354284961797',
#    'in_reply_to_screen_name': 'HighwaysNWEST',
#    'in_reply_to_status_id': 1085584485507350529,
#    'in_reply_to_status_id_str': '1085584485507350529',
#    'in_reply_to_user_id': 224671374,
#    'in_reply_to_user_id_str': '224671374',
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'quote_count': 0,
#    'reply_count': 4,
#    'retweet_count': 7,
#    'retweeted': False,
#    'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#    'text': 'All traffic caught within the closure has now been released. Thanks for your patience if you were held up. The road… https://t.co/NnLxpEMYHC',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Dec 09 15:41:20 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "OFFICIAL FEED. Live traffic information from Highways England. We manage England's motorways and major A roads. Contact: http://bit.ly/1DslcUg",
#     'favourites_count': 740,
#     'follow_request_sent': None,
#     'followers_count': 76316,
#     'following': None,
#     'friends_count': 32,
#     'geo_enabled': False,
#     'id': 224671374,
#     'id_str': '224671374',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 503,
#     'location': 'North West, England',
#     'name': 'Highways England',
#     'notifications': None,
#     'profile_background_color': '1B518B',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/224671374/1542121405',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1023754912663040000/JRWEsguX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1023754912663040000/JRWEsguX_normal.jpg',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '1B518B',
#     'profile_sidebar_fill_color': 'E3F1FB',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'HighwaysNWEST',
#     'statuses_count': 82423,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://highwaysengland.co.uk/',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @HighwaysNWEST: All traffic caught within the closure has now been released. Thanks for your patience if you were held up. The road rema…',
#   'timestamp_ms': '1547669691443',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jul 23 20:06:00 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "I'm Paul Salkeld one of the organisers of Cumbria charity truck fair I also drive for m&n garner bulk haulage my opinions and comments are my own \U0001f920👍",
#    'favourites_count': 10850,
#    'follow_request_sent': None,
#    'followers_count': 1018,
#    'following': None,
#    'friends_count': 715,
#    'geo_enabled': False,
#    'id': 756943464307318785,
#    'id_str': '756943464307318785',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Carlisle, England',
#    'name': 'Cumbria charity truck fair',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/756943464307318785/1540762802',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1046508177628573697/TudbOG5i_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1046508177628573697/TudbOG5i_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Cctf2',
#    'statuses_count': 3572,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://www.facebook.com/CumbriaCharityTruckFair/',
#    'utc_offset': None,
#    'verified': False}}]

# %% [markdown]
# track1 =[ "road closed", "roads closed", "road blocked", "street blocked", "roadclosed"]
#
#
#
# |Stream| params| json file| # of tweets |search terms|
# |---| --- | --- | --- | ---|
# |verified| tweet_mode='extended'| ./tweepy_scrape_20190114_23_22.json | 2| track1|
# |experimental| none?| ./tweepy_scrape_20190114_23_33.json | 3| track1|

# %%
# first group of tweets

# available in my folder only
# json_df = pd.read_("./tweepy_scrape_20190111_11_5713.json")
# json_df = pd.read_json("./tweepy_scrape_20190114_23_22.json", lines = True)
# json_df = pd.read_json("./tweepy_scrape_20190114_23_33.json", lines = True)

# available in data folder
json_df = pd.read_json("../data/AT_stream/scrape_20190116_12_15.json", lines = True)


# "extended tweets"

# %% [markdown]
# ## Part 3: Examine Tweets

# %%
print(json_df.shape)
json_df.head()
# Out:
# (4, 32)
#    contributors  coordinates          created_at  \
# 0           NaN          NaN 2019-01-16 20:14:10
# 1           NaN          NaN 2019-01-16 20:14:13
# 2           NaN          NaN 2019-01-16 20:14:15
# 3           NaN          NaN 2019-01-16 20:14:51
#
#                                             entities  favorite_count  \
# 0  {'urls': [], 'user_mentions': [], 'symbols': [...               0
# 1  {'urls': [], 'user_mentions': [{'name': 'Black...               0
# 2  {'urls': [], 'user_mentions': [], 'symbols': [...               0
# 3  {'urls': [], 'user_mentions': [{'name': 'Highw...               0
#
#    favorited filter_level  geo                   id               id_str  \
# 0      False          low  NaN  1085631317751066626  1085631317751066624
# 1      False          low  NaN  1085631330384334848  1085631330384334848
# 2      False          low  NaN  1085631338693214208  1085631338693214208
# 3      False          low  NaN  1085631487955869697  1085631487955869696
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
#
#                              quoted_status_permalink  reply_count  \
# 0  {'display': 'twitter.com/kil889/status/…', 'ex...            0
# 1  {'display': 'twitter.com/rhyemswturtle/…', 'ex...            0
# 2                                                NaN            0
# 3                                                NaN            0
#
#    retweet_count  retweeted  \
# 0              0      False
# 1              0      False
# 2              0      False
# 3              0      False
#
#                                     retweeted_status  \
# 0                                                NaN
# 1  {'entities': {'urls': [{'display_url': 'twitte...
# 2                                                NaN
# 3  {'quote_count': 0, 'id': 1085601354284961797, ...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="https://ifttt.com" rel="nofollow">IFT...
# 3  <a href="http://twitter.com/download/android" ...
#
#                                                 text            timestamp_ms  \
# 0  Just block anybody who willingly listens to St... 2019-01-16 20:14:10.863
# 1  RT @BlkNrdProblems: Beloved, that's called str... 2019-01-16 20:14:13.875
# 2  TFL UPDATE: TfLTrafficNews: London Road SM4 is... 2019-01-16 20:14:15.856
# 3  RT @HighwaysNWEST: All traffic caught within t... 2019-01-16 20:14:51.443
#
#    truncated                                               user
# 0      False  {'name': 'Tragedy Khadafi verse on Strange Fru...
# 1      False  {'name': 'lmao y'all wild', 'screen_name': 'An...
# 2      False  {'name': 'Bob', 'screen_name': 'thelondonbob01...
# 3      False  {'name': 'Cumbria charity truck fair', 'screen...
#
# [4 rows x 32 columns]

# %%
tweets_data = []
notParsed = []
tweets_file = open("../data/AT_stream/scrape_20190116_12_15.json","r")
for line in tweets_file:    
    if line.strip():    
        try:
            tweet=json.loads(line)
            tweets_data.append(tweet)
        except:
            notParsed.append(line)
            continue
print(len(tweets_data))
print('Could not parse: ', len(notParsed))
# Out:
# 4
# Could not parse:  0

# %%
tweet_cols = ['coordinates', 'created_at', 
#                'full_text',
              'text','geo', 'id', 'place', 'user']


sample_tweets_dict = [{col:tweet[col] for col in tweet_cols } for tweet in tweets_data]

# To flatten all nested dictionaries
# DOES NOT FLATTEN LISTS
# Look for any instances of nested lists during cleaning
sample_tweets_df = pd.io.json.json_normalize(sample_tweets_dict)
sample_tweets_df
# Out:
#   coordinates                      created_at   geo                   id  \
# 0        None  Wed Jan 16 20:14:10 +0000 2019  None  1085631317751066626
# 1        None  Wed Jan 16 20:14:13 +0000 2019  None  1085631330384334848
# 2        None  Wed Jan 16 20:14:15 +0000 2019  None  1085631338693214208
# 3        None  Wed Jan 16 20:14:51 +0000 2019  None  1085631487955869697
#
#   place                                               text  \
# 0  None  Just block anybody who willingly listens to St...
# 1  None  RT @BlkNrdProblems: Beloved, that's called str...
# 2  None  TFL UPDATE: TfLTrafficNews: London Road SM4 is...
# 3  None  RT @HighwaysNWEST: All traffic caught within t...
#
#    user.contributors_enabled                 user.created_at  \
# 0                      False  Sat Apr 03 01:38:23 +0000 2010
# 1                      False  Sat Oct 24 15:46:11 +0000 2015
# 2                      False  Mon Jul 04 20:11:00 +0000 2016
# 3                      False  Sat Jul 23 20:06:00 +0000 2016
#
#    user.default_profile  user.default_profile_image      ...        \
# 0                 False                       False      ...
# 1                 False                       False      ...
# 2                  True                       False      ...
# 3                  True                       False      ...
#
#   user.profile_text_color  user.profile_use_background_image user.protected  \
# 0                  333333                               True          False
# 1                  000000                              False          False
# 2                  333333                               True          False
# 3                  333333                               True          False
#
#    user.screen_name user.statuses_count  user.time_zone  user.translator_type  \
# 0     MiqueOnTheMix              138078            None                  none
# 1     AnAcidTweeter                1833            None                  none
# 2    thelondonbob01              104997            None                  none
# 3             Cctf2                3572            None                  none
#
#                                             user.url user.utc_offset  \
# 0                http://Soundcloud.com/miqueonthemix            None
# 1                                               None            None
# 2                                               None            None
# 3  https://www.facebook.com/CumbriaCharityTruckFair/            None
#
#    user.verified
# 0          False
# 1          False
# 2          False
# 3          False
#
# [4 rows x 45 columns]

# %%
json_df.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'entities',
#        'favorite_count', 'favorited', 'filter_level', 'geo', 'id', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#        'quote_count', 'reply_count', 'retweet_count', 'retweeted',
#        'retweeted_status', 'source', 'text', 'timestamp_ms', 'truncated',
#        'user'],
#       dtype='object')

# %%
# json_df.loc[:, 'lang':]

# %%
list = json_df.loc[:, 'text']
# print(list)
for i in range(len(list)):
    print(i, list[i])
    print("--------")
# Out:
# 0 RT @mandy1714: @hertscc is this the same incident that has closed A41 North and Southbound. 3 hours of Utter chaos. No diversion in place b…
# --------
